# %% [markdown]
# ### Load model

# %%
MODEL_PATH = '../Models/Pres_hybrid_CF.h5'
# DATA_PATH =  '../Datasets/Dataset_train_CF.csv'
DATA_PATH = '../Datasets/dataset_reduced.csv'

SEED = 32

# %%
from tensorflow.keras.models import load_model

model = load_model(MODEL_PATH)

# %% [markdown]
# ### Read data and predict values

# %%
import pandas as pd

data = pd.read_csv(DATA_PATH, index_col=0)

# X = data.drop('P_res', axis=1)
X = data

y_pred_nn = model.predict(X)
# Out:
# 15067/15067 [==============================] - 7s 448us/step

# %% [markdown]
# ### Train decision tree

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.metrics import make_scorer, mean_squared_error


# X_train, X_test, y_train, y_test = train_test_split(X, y_pred_nn, test_size=0.2, random_state=SEED)
X_train = X
y_train = y_pred_nn

tree = DecisionTreeRegressor(random_state=SEED)

tree_params = {
    "max_depth": [4, 16, 32, 64],
    "criterion": ['squared_error'],
    "min_samples_split": [0.01],
    "min_samples_leaf": [0.01],
}

scoring = make_scorer(mean_squared_error, greater_is_better=False)
grid = GridSearchCV(tree, tree_params, scoring=scoring, n_jobs=-1, refit=True, cv=5, verbose=1)

grid.fit(X_train, y_train)

model_tree = grid.best_estimator_
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits

# %% [markdown]
# ### Get results

# %%
from sklearn.metrics import mean_squared_error
from sklearn.tree import export_text
import numpy as np

# y_pred_tree = model_tree.predict(X_test)
y_pred_tree = model_tree.predict(X_train)

# mse_tree = mean_squared_error(y_test, y_pred_tree)
mse_tree = mean_squared_error(y_pred_nn, y_pred_tree)

# Calcular RMSE
rmse_tree = np.sqrt(mse_tree)
print(f"RMSE tree: {rmse_tree}")

tree_rules = export_text(model_tree, feature_names=list(X.columns))
print("Tree rules:\n", tree_rules)
# Out:
# RMSE tree: 0.5529425735050145
# Tree rules:
#  |--- hub_temperature <= -0.19
# |   |--- V <= 0.20
# |   |   |--- Out_temperature <= -0.83
# |   |   |   |--- V <= -0.46
# |   |   |   |   |--- V <= -0.87
# |   |   |   |   |   |--- V <= -1.07
# |   |   |   |   |   |   |--- value: [0.06]
# |   |   |   |   |   |--- V >  -1.07
# |   |   |   |   |   |   |--- value: [0.10]
# |   |   |   |   |--- V >  -0.87
# |   |   |   |   |   |--- Out_temperature <= -1.44
# |   |   |   |   |   |   |--- value: [0.23]
# |   |   |   |   |   |--- Out_temperature >  -1.44
# |   |   |   |   |   |   |--- Out_temperature <= -1.15
# |   |   |   |   |   |   |   |--- value: [0.17]
# |   |   |   |   |   |   |--- Out_temperature >  -1.15
# |   |   |   |   |   |   |   |--- value: [0.13]
# |   |   |   |--- V >  -0.46
# |   |   |   |   |--- Out_temperature <= -1.39
# |   |   |   |   |   |--- V <= -0.17
# |   |   |   |   |   |   |--- value: [0.33]
# |   |   |   |   |   |--- V >  -0.17
# |   |   |   |   |   |   |--- value: [0.46]
# |   |   |   |   |--- Out_temperature >  -1.39
# |   |   |   |   |   |--- V <= -0.11
# |   |   |   |   |   |   |--- Out_temperature <= -1.14
# |   |   |   |   |   |   |   |--- value: [0.25]
# |   |   |   |   |   |   |--- Out_temperature >  -1.14
# |   |   |   |   |   |   |   |--- value: [0.19]
# |   |   |   |   |   |--- V >  -0.11
# |   |   |   |   |   |   |--- Out_temperature <= -1.11
# |   |   |   |   |   |   |   |--- value: [0.33]
# |   |   |   |   |   |   |--- Out_temperature >  -1.11
# |   |   |   |   |   |   |   |--- value: [0.26]
# |   |   |--- Out_temperature >  -0.83
# |   |   |   |--- hub_temperature <= -0.52
# |   |   |   |   |--- V <= -0.37
# |   |   |   |   |   |--- V <= -0.79
# |   |   |   |   |   |   |--- value: [0.03]
# |   |   |   |   |   |--- V >  -0.79
# |   |   |   |   |   |   |--- value: [0.08]
# |   |   |   |   |--- V >  -0.37
# |   |   |   |   |   |--- hub_temperature <= -0.85
# |   |   |   |   |   |   |--- value: [0.18]
# |   |   |   |   |   |--- hub_temperature >  -0.85
# |   |   |   |   |   |   |--- value: [0.12]
# |   |   |   |--- hub_temperature >  -0.52
# |   |   |   |   |--- Out_temperature <= -0.58
# |   |   |   |   |   |--- value: [0.08]
# |   |   |   |   |--- Out_temperature >  -0.58
# |   |   |   |   |   |--- nacelle_angle <= -0.29
# |   |   |   |   |   |   |--- W <= -0.58
# |   |   |   |   |   |   |   |--- value: [-0.00]
# |   |   |   |   |   |   |--- W >  -0.58
# |   |   |   |   |   |   |   |--- value: [-0.03]
# |   |   |   |   |   |--- nacelle_angle >  -0.29
# |   |   |   |   |   |   |--- V <= -0.18
# |   |   |   |   |   |   |   |--- V <= -0.69
# |   |   |   |   |   |   |   |   |--- value: [0.01]
# |   |   |   |   |   |   |   |--- V >  -0.69
# |   |   |   |   |   |   |   |   |--- value: [0.03]
# |   |   |   |   |   |   |--- V >  -0.18
# |   |   |   |   |   |   |   |--- value: [0.07]
# |   |--- V >  0.20
# |   |   |--- nacelle_angle <= -1.25
# |   |   |   |--- V <= 1.12
# |   |   |   |   |--- value: [0.74]
# |   |   |   |--- V >  1.12
# |   |   |   |   |--- value: [2.12]
# |   |   |--- nacelle_angle >  -1.25
# |   |   |   |--- Vane_angle <= -0.41
# |   |   |   |   |--- V <= 1.32
# |   |   |   |   |   |--- nacelle_angle <= 0.37
# |   |   |   |   |   |   |--- value: [0.31]
# |   |   |   |   |   |--- nacelle_angle >  0.37
# |   |   |   |   |   |   |--- value: [-0.04]
# |   |   |   |   |--- V >  1.32
# |   |   |   |   |   |--- value: [-0.61]
# |   |   |   |--- Vane_angle >  -0.41
# |   |   |   |   |--- hub_temperature <= -0.87
# |   |   |   |   |   |--- Out_temperature <= -1.25
# |   |   |   |   |   |   |--- value: [0.94]
# |   |   |   |   |   |--- Out_temperature >  -1.25
# |   |   |   |   |   |   |--- nacelle_angle_c <= 0.22
# |   |   |   |   |   |   |   |--- value: [0.37]
# |   |   |   |   |   |   |--- nacelle_angle_c >  0.22
# |   |   |   |   |   |   |   |--- value: [0.59]
# |   |   |   |   |--- hub_temperature >  -0.87
# |   |   |   |   |   |--- V <= 1.15
# |   |   |   |   |   |   |--- Rotor_temperature <= -0.02
# |   |   |   |   |   |   |   |--- V <= 0.54
# |   |   |   |   |   |   |   |   |--- value: [0.38]
# |   |   |   |   |   |   |   |--- V >  0.54
# |   |   |   |   |   |   |   |   |--- value: [0.61]
# |   |   |   |   |   |   |--- Rotor_temperature >  -0.02
# |   |   |   |   |   |   |   |--- value: [0.21]
# |   |   |   |   |   |--- V >  1.15
# |   |   |   |   |   |   |--- nacelle_angle <= 0.49
# |   |   |   |   |   |   |   |--- Rotor_temperature <= -0.10
# |   |   |   |   |   |   |   |   |--- value: [0.39]
# |   |   |   |   |   |   |   |--- Rotor_temperature >  -0.10
# |   |   |   |   |   |   |   |   |--- value: [0.03]
# |   |   |   |   |   |   |--- nacelle_angle >  0.49
# |   |   |   |   |   |   |   |--- value: [-0.35]
# |--- hub_temperature >  -0.19
# |   |--- W <= 0.80
# |   |   |--- Rotor_temperature <= 0.92
# |   |   |   |--- W <= -0.25
# |   |   |   |   |--- hub_temperature <= 0.57
# |   |   |   |   |   |--- Out_temperature <= -0.08
# |   |   |   |   |   |   |--- Out_temperature <= -0.29
# |   |   |   |   |   |   |   |--- value: [0.02]
# |   |   |   |   |   |   |--- Out_temperature >  -0.29
# |   |   |   |   |   |   |   |--- value: [-0.01]
# |   |   |   |   |   |--- Out_temperature >  -0.08
# |   |   |   |   |   |   |--- W <= -0.71
# |   |   |   |   |   |   |   |--- Out_temperature <= 0.41
# |   |   |   |   |   |   |   |   |--- theta <= -0.12
# |   |   |   |   |   |   |   |   |   |--- value: [-0.03]
# |   |   |   |   |   |   |   |   |--- theta >  -0.12
# |   |   |   |   |   |   |   |   |   |--- value: [-0.01]
# |   |   |   |   |   |   |   |--- Out_temperature >  0.41
# |   |   |   |   |   |   |   |   |--- Out_temperature <= 0.72
# |   |   |   |   |   |   |   |   |   |--- value: [-0.05]
# |   |   |   |   |   |   |   |   |--- Out_temperature >  0.72
# |   |   |   |   |   |   |   |   |   |--- value: [-0.07]
# |   |   |   |   |   |   |--- W >  -0.71
# |   |   |   |   |   |   |   |--- V <= -0.42
# |   |   |   |   |   |   |   |   |--- value: [-0.09]
# |   |   |   |   |   |   |   |--- V >  -0.42
# |   |   |   |   |   |   |   |   |--- value: [-0.04]
# |   |   |   |   |--- hub_temperature >  0.57
# |   |   |   |   |   |--- W <= -0.81
# |   |   |   |   |   |   |--- Out_temperature <= 1.17
# |   |   |   |   |   |   |   |--- theta <= -0.11
# |   |   |   |   |   |   |   |   |--- Out_temperature <= 0.71
# |   |   |   |   |   |   |   |   |   |--- value: [-0.06]
# |   |   |   |   |   |   |   |   |--- Out_temperature >  0.71
# |   |   |   |   |   |   |   |   |   |--- value: [-0.09]
# |   |   |   |   |   |   |   |--- theta >  -0.11
# |   |   |   |   |   |   |   |   |--- value: [-0.05]
# |   |   |   |   |   |   |--- Out_temperature >  1.17
# |   |   |   |   |   |   |   |--- Out_temperature <= 1.59
# |   |   |   |   |   |   |   |   |--- value: [-0.10]
# |   |   |   |   |   |   |   |--- Out_temperature >  1.59
# |   |   |   |   |   |   |   |   |--- value: [-0.14]
# |   |   |   |   |   |--- W >  -0.81
# |   |   |   |   |   |   |--- hub_temperature <= 1.17
# |   |   |   |   |   |   |   |--- W <= -0.52
# |   |   |   |   |   |   |   |   |--- value: [-0.12]
# |   |   |   |   |   |   |   |--- W >  -0.52
# |   |   |   |   |   |   |   |   |--- value: [-0.15]
# |   |   |   |   |   |   |--- hub_temperature >  1.17
# |   |   |   |   |   |   |   |--- value: [-0.20]
# |   |   |   |--- W >  -0.25
# |   |   |   |   |--- hub_temperature <= 0.42
# |   |   |   |   |   |--- hub_temperature <= 0.02
# |   |   |   |   |   |   |--- nacelle_angle_c <= 0.27
# |   |   |   |   |   |   |   |--- value: [-0.08]
# |   |   |   |   |   |   |--- nacelle_angle_c >  0.27
# |   |   |   |   |   |   |   |--- value: [0.03]
# |   |   |   |   |   |--- hub_temperature >  0.02
# |   |   |   |   |   |   |--- nacelle_angle_c <= -0.07
# |   |   |   |   |   |   |   |--- value: [-0.20]
# |   |   |   |   |   |   |--- nacelle_angle_c >  -0.07
# |   |   |   |   |   |   |   |--- value: [-0.10]
# |   |   |   |   |--- hub_temperature >  0.42
# |   |   |   |   |   |--- W <= 0.35
# |   |   |   |   |   |   |--- hub_temperature <= 0.84
# |   |   |   |   |   |   |   |--- value: [-0.19]
# |   |   |   |   |   |   |--- hub_temperature >  0.84
# |   |   |   |   |   |   |   |--- value: [-0.29]
# |   |   |   |   |   |--- W >  0.35
# |   |   |   |   |   |   |--- value: [-0.38]
# |   |   |--- Rotor_temperature >  0.92
# |   |   |   |--- W <= 0.07
# |   |   |   |   |--- W <= -0.55
# |   |   |   |   |   |--- Out_temperature <= 1.54
# |   |   |   |   |   |   |--- theta <= -0.15
# |   |   |   |   |   |   |   |--- value: [-0.14]
# |   |   |   |   |   |   |--- theta >  -0.15
# |   |   |   |   |   |   |   |--- value: [-0.09]
# |   |   |   |   |   |--- Out_temperature >  1.54
# |   |   |   |   |   |   |--- W <= -0.98
# |   |   |   |   |   |   |   |--- value: [-0.17]
# |   |   |   |   |   |   |--- W >  -0.98
# |   |   |   |   |   |   |   |--- value: [-0.24]
# |   |   |   |   |--- W >  -0.55
# |   |   |   |   |   |--- hub_temperature <= 1.36
# |   |   |   |   |   |   |--- value: [-0.19]
# |   |   |   |   |   |--- hub_temperature >  1.36
# |   |   |   |   |   |   |--- value: [-0.37]
# |   |   |   |--- W >  0.07
# |   |   |   |   |--- hub_temperature <= 1.18
# |   |   |   |   |   |--- value: [-0.27]
# |   |   |   |   |--- hub_temperature >  1.18
# |   |   |   |   |   |--- value: [-0.69]
# |   |--- W >  0.80
# |   |   |--- hub_temperature <= 0.79
# |   |   |   |--- nacelle_angle_c <= -1.15
# |   |   |   |   |--- value: [0.43]
# |   |   |   |--- nacelle_angle_c >  -1.15
# |   |   |   |   |--- V <= 0.87
# |   |   |   |   |   |--- Out_temperature <= 0.20
# |   |   |   |   |   |   |--- value: [-0.08]
# |   |   |   |   |   |--- Out_temperature >  0.20
# |   |   |   |   |   |   |--- value: [-0.55]
# |   |   |   |   |--- V >  0.87
# |   |   |   |   |   |--- Out_temperature <= 0.28
# |   |   |   |   |   |   |--- nacelle_angle <= 0.54
# |   |   |   |   |   |   |   |--- value: [-0.43]
# |   |   |   |   |   |   |--- nacelle_angle >  0.54
# |   |   |   |   |   |   |   |--- value: [-0.92]
# |   |   |   |   |   |--- Out_temperature >  0.28
# |   |   |   |   |   |   |--- value: [-1.11]
# |   |   |--- hub_temperature >  0.79
# |   |   |   |--- Out_temperature <= 1.12
# |   |   |   |   |--- value: [-1.10]
# |   |   |   |--- Out_temperature >  1.12
# |   |   |   |   |--- value: [-1.86]
