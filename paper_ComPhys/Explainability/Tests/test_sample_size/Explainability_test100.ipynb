# %% [markdown]
# # SHAP values
#
# Deep SHAP is a high-speed approximation algorithm for SHAP values in deep learning models that builds on a connection with DeepLIFT described in the SHAP NIPS paper.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import shap

from tensorflow.keras.models import load_model

DATA_DIR = '../Datasets/'
MODELS_DIR = '../Models/'

# TRAIN_PATH = DATA_DIR + '/Dataset_train.csv'
# TRAIN_CF_PATH = DATA_DIR + '/Dataset_train_CF.csv'

TEST_PATH = DATA_DIR + '/Dataset_test.csv'
TEST_CF_PATH = DATA_DIR + '/Dataset_test_CF.csv'

MODEL_PATH = MODELS_DIR + 'Pres_hybrid.h5'
MODEL_CF_PATH = MODELS_DIR + 'Pres_hybrid_CF.h5'

SAMPLES = 100
# Out:
# IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html
# 2024-10-02 13:48:53.340869: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-10-02 13:48:53.373012: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-10-02 13:48:53.515034: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-02 13:48:53.515099: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-02 13:48:53.544863: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-02 13:48:53.609050: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-10-02 13:48:53.610297: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-02 13:48:54.461283: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# Load datasets and model, then fit explainer and return SHAP values:

# %%
def show_shap_values(test_path, model_path, reduced_size=None):
    
    model = load_model(model_path)

    X_test = pd.read_csv(test_path, index_col=0)
    X_test.reset_index(drop=True, inplace=True)

    if reduced_size:
        test_data = X_test.sample(n=reduced_size, replace=False).to_numpy()
    else:
        test_data = X_test.to_numpy()

    explainer = shap.Explainer(model, test_data, feature_names=X_test.columns)
    shap_values = explainer(test_data)

    return shap_values

# %% [markdown]
# ## Default model
#
# Plots for the vanilla model and dataset.

# %%
shap_values_default = show_shap_values(TEST_PATH, MODEL_PATH, SAMPLES)
# Out:
# 2024-10-02 09:16:34.637606: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:274] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 shap_values_default = show_shap_values(TEST_PATH, MODEL_PATH, SAMPLES)
#
# Cell In[2], line 14, in show_shap_values(test_path, model_path, reduced_size)
#      11     test_data = X_test.to_numpy()
#      13 explainer = shap.Explainer(model, test_data, feature_names=X_test.columns)
# ---> 14 shap_values = explainer(test_data)
#      16 return shap_values
#
# File ~/Work/UGR/Calculations/WindTurbines_hybrid/WT_hybrid_venv/lib/python3.10/site-packages/shap/explainers/_permutation.py:79, in PermutationExplainer.__call__(self, max_evals, main_effects, error_bounds, batch_size, outputs, silent, *args)
#      75 def __call__(self, *args, max_evals=500, main_effects=False, error_bounds=False, batch_size="auto",
#      76              outputs=None, silent=False):
#      77     """ Explain the output of the model on the given arguments.
#      78     """
# ---> 79     return super().__call__(
#      80         *args, max_evals=max_evals, main_effects=main_effects, error_bounds=error_bounds, batch_size=batch_size,
#      81         outputs=outputs, silent=silent
#      82     )
#
# File ~/Work/UGR/Calculations/WindTurbines_hybrid/WT_hybrid_venv/lib/python3.10/site-packages/shap/explainers/_explainer.py:267, in Explainer.__call__(self, max_evals, main_effects, error_bounds, batch_size, outputs, silent, *args, **kwargs)
#     265     feature_names = [[] for _ in range(len(args))]
#     266 for row_args in show_progress(zip(*args), num_rows, self.__class__.__name__+" explainer", silent):
# --> 267     row_result = self.explain_row(
#     268         *row_args, max_evals=max_evals, main_effects=main_effects, error_bounds=error_bounds,
#     269         batch_size=batch_size, outputs=outputs, silent=silent, **kwargs
#     270     )
#     271     values.append(row_result.get("values", None))
#     272     output_indices.append(row_result.get("output_indices", None))
#
# File ~/Work/UGR/Calculations/WindTurbines_hybrid/WT_hybrid_venv/lib/python3.10/site-packages/shap/explainers/_permutation.py:137, in PermutationExplainer.explain_row(self, max_evals, main_effects, error_bounds, batch_size, outputs, silent, *row_args)
#     134     i += 1
#     136 # evaluate the masked model
# --> 137 outputs = fm(masks, zero_index=0, batch_size=batch_size)
#     139 if row_values is None:
#     140     row_values = np.zeros((len(fm),) + outputs.shape[1:])
#
# File ~/Work/UGR/Calculations/WindTurbines_hybrid/WT_hybrid_venv/lib/python3.10/site-packages/shap/utils/_masked_model.py:59, in MaskedModel.__call__(self, masks, zero_index, batch_size)
#      57 if len(masks.shape) == 1:
#      58     if getattr(self.masker, "supports_delta_masking", False):
# ---> 59         return self._delta_masking_call(masks, zero_index=zero_index, batch_size=batch_size)
#      61     # we need to convert from delta masking to a full masking call because we were given a delta masking
#      62     # input but the masker does not support delta masking
#      63     else:
#      64         full_masks = np.zeros((int(np.sum(masks >= 0)), self._masker_cols), dtype=bool)
#
# File ~/Work/UGR/Calculations/WindTurbines_hybrid/WT_hybrid_venv/lib/python3.10/site-packages/shap/utils/_masked_model.py:215, in MaskedModel._delta_masking_call(self, masks, zero_index, batch_size)
#     213 last_outs = np.zeros((varying_rows.shape[1],) + outputs.shape[1:])
#     214 #print("link", self.link)
# --> 215 _build_fixed_output(averaged_outs, last_outs, outputs, batch_positions, varying_rows, num_varying_rows, self.link, self._linearizing_weights)
#     217 return averaged_outs
#
# File ~/Work/UGR/Calculations/WindTurbines_hybrid/WT_hybrid_venv/lib/python3.10/site-packages/shap/utils/_masked_model.py:362, in _build_fixed_output(averaged_outs, last_outs, outputs, batch_positions, varying_rows, num_varying_rows, link, linearizing_weights)
#     360     _build_fixed_single_output(averaged_outs, last_outs, outputs, batch_positions, varying_rows, num_varying_rows, link, linearizing_weights)
#     361 else:
# --> 362     _build_fixed_multi_output(averaged_outs, last_outs, outputs, batch_positions, varying_rows, num_varying_rows, link, linearizing_weights)
#
# File ~/Work/UGR/Calculations/WindTurbines_hybrid/WT_hybrid_venv/lib/python3.10/site-packages/numba/core/dispatcher.py:420, in _DispatcherBase._compile_for_args(self, *args, **kws)
#     418 return_val = None
#     419 try:
# --> 420     return_val = self.compile(tuple(argtypes))
#     421 except errors.ForceLiteralArg as e:
#     422     # Received request for compiler re-entry with the list of arguments
#     423     # indicated by e.requested_args.
#     424     # First, check if any of these args are already Literal-ized
#     425     already_lit_pos = [i for i in e.requested_args
#     426                        if isinstance(args[i], types.Literal)]
#
# File ~/Work/UGR/Calculations/WindTurbines_hybrid/WT_hybrid_venv/lib/python3.10/site-packages/numba/core/dispatcher.py:957, in Dispatcher.compile(self, sig)
#     955 with ev.trigger_event("numba:compile", data=ev_details):
#     956     try:
# --> 957         cres = self._compiler.compile(args, return_type)
#     958     except errors.ForceLiteralArg as e:
#     959         def folded(args, kws):
#
# File ~/Work/UGR/Calculations/WindTurbines_hybrid/WT_hybrid_venv/lib/python3.10/site-packages/numba/core/dispatcher.py:125, in _FunctionCompiler.compile(self, args, return_type)
#     124 def compile(self, args, return_type):
# --> 125     status, retval = self._compile_cached(args, return_type)
#     126     if status:
#     127         return retval
#
# File ~/Work/UGR/Calculations/WindTurbines_hybrid/WT_hybrid_venv/lib/python3.10/site-packages/numba/core/dispatcher.py:139, in _FunctionCompiler._compile_cached(self, args, return_type)
#     136     pass
#     138 try:
# --> 139     retval = self._compile_core(args, return_type)
#     140 except errors.TypingError as e:
#     141     self._failed_cache[key] = e
#
# File ~/Work/UGR/Calculations/WindTurbines_hybrid/WT_hybrid_venv/lib/python3.10/site-packages/numba/core/dispatcher.py:152, in _FunctionCompiler._compile_core(self, args, return_type)
#     149 flags = self._customize_flags(flags)
#     151 impl = self._get_implementation(args, {})
# --> 152 cres = compiler.compile_extra(self.targetdescr.typing_context,
#     153                               self.targetdescr.target_context,
#     154                               impl,
#     155                               args=args, return_type=return_type,
#     156                               flags=flags, locals=self.locals,
#     157                               pipeline_class=self.pipeline_class)
#     158 # Check typing error if object mode is used
#     159 if cres.typing_error is not None and not flags.enable_pyobject:
#
# File ~/Work/UGR/Calculations/WindTurbines_hybrid/WT_hybrid_venv/lib/python3.10/site-packages/numba/core/compiler.py:751, in compile_extra(typingctx, targetctx, func, args, return_type, flags, locals, library, pipeline_class)
#     727 """Compiler entry point
#     728
#     729 Parameter
#    (...)
#     747     compiler pipeline
#     748 """
#     749 pipeline = pipeline_class(typingctx, targetctx, library,
#     750                           args, return_type, flags, locals)
# --> 751 return pipeline.compile_extra(func)
#
# File ~/Work/UGR/Calculations/WindTurbines_hybrid/WT_hybrid_venv/lib/python3.10/site-packages/numba/core/compiler.py:445, in CompilerBase.compile_extra(self, func)
#     443 self.state.lifted = ()
#     444 self.state.lifted_from = None
# --> 445 return self._compile_bytecode()
#
# File ~/Work/UGR/Calculations/WindTurbines_hybrid/WT_hybrid_venv/lib/python3.10/site-packages/numba/core/compiler.py:513, in CompilerBase._compile_bytecode(self)
#     509 """
#     510 Populate and run pipeline for bytecode input
#     511 """
#     512 assert self.state.func_ir is None
# --> 513 return self._compile_core()
#
# File ~/Work/UGR/Calculations/WindTurbines_hybrid/WT_hybrid_venv/lib/python3.10/site-packages/numba/core/compiler.py:479, in CompilerBase._compile_core(self)
#     477 res = None
#     478 try:
# --> 479     pm.run(self.state)
#     480     if self.state.cr is not None:
#     481         break
#
# File ~/Work/UGR/Calculations/WindTurbines_hybrid/WT_hybrid_venv/lib/python3.10/site-packages/numba/core/compiler_machinery.py:356, in PassManager.run(self, state)
#     354 pass_inst = _pass_registry.get(pss).pass_inst
#     355 if isinstance(pass_inst, CompilerPass):
# --> 356     self._runPass(idx, pass_inst, state)
#     357 else:
#     358     raise BaseException("Legacy pass in use")
#
# File ~/Work/UGR/Calculations/WindTurbines_hybrid/WT_hybrid_venv/lib/python3.10/site-packages/numba/core/compiler_lock.py:35, in _CompilerLock.__call__.<locals>._acquire_compile_lock(*args, **kwargs)
#      32 @functools.wraps(func)
#      33 def _acquire_compile_lock(*args, **kwargs):
#      34     with self:
# ---> 35         return func(*args, **kwargs)
#
# File ~/Work/UGR/Calculations/WindTurbines_hybrid/WT_hybrid_venv/lib/python3.10/site-packages/numba/core/compiler_machinery.py:311, in PassManager._runPass(self, index, pss, internal_state)
#     309     mutated |= check(pss.run_initialization, internal_state)
#     310 with SimpleTimer() as pass_time:
# --> 311     mutated |= check(pss.run_pass, internal_state)
#     312 with SimpleTimer() as finalize_time:
#     313     mutated |= check(pss.run_finalizer, internal_state)
#
# File ~/Work/UGR/Calculations/WindTurbines_hybrid/WT_hybrid_venv/lib/python3.10/site-packages/numba/core/compiler_machinery.py:273, in PassManager._runPass.<locals>.check(func, compiler_state)
#     272 def check(func, compiler_state):
# --> 273     mangled = func(compiler_state)
#     274     if mangled not in (True, False):
#     275         msg = ("CompilerPass implementations should return True/False. "
#     276                "CompilerPass with name '%s' did not.")
#
# File ~/Work/UGR/Calculations/WindTurbines_hybrid/WT_hybrid_venv/lib/python3.10/site-packages/numba/core/typed_passes.py:468, in BaseNativeLowering.run_pass(self, state)
#     465 with targetctx.push_code_library(library):
#     466     lower = self.lowering_class(targetctx, library, fndesc, interp,
#     467                                 metadata=metadata)
# --> 468     lower.lower()
#     469     if not flags.no_cpython_wrapper:
#     470         lower.create_cpython_wrapper(flags.release_gil)
#
# File ~/Work/UGR/Calculations/WindTurbines_hybrid/WT_hybrid_venv/lib/python3.10/site-packages/numba/core/lowering.py:210, in BaseLower.lower(self)
#     207 self.context.post_lowering(self.module, self.library)
#     209 # Materialize LLVM Module
# --> 210 self.library.add_ir_module(self.module)
#
# File ~/Work/UGR/Calculations/WindTurbines_hybrid/WT_hybrid_venv/lib/python3.10/site-packages/numba/core/codegen.py:726, in CPUCodeLibrary.add_ir_module(self, ir_module)
#     724 self._raise_if_finalized()
#     725 assert isinstance(ir_module, llvmir.Module)
# --> 726 ir = cgutils.normalize_ir_text(str(ir_module))
#     727 ll_module = ll.parse_assembly(ir)
#     728 ll_module.name = ir_module.name
#
# File ~/Work/UGR/Calculations/WindTurbines_hybrid/WT_hybrid_venv/lib/python3.10/site-packages/llvmlite/ir/module.py:242, in Module.__repr__(self)
#     236 lines += [
#     237     '; ModuleID = "%s"' % (self.name,),
#     238     'target triple = "%s"' % (self.triple,),
#     239     'target datalayout = "%s"' % (self.data_layout,),
#     240     '']
#     241 # Body
# --> 242 lines += self._get_body_lines()
#     243 # Metadata
#     244 lines += self._get_metadata_lines()
#
# File ~/Work/UGR/Calculations/WindTurbines_hybrid/WT_hybrid_venv/lib/python3.10/site-packages/llvmlite/ir/module.py:212, in Module._get_body_lines(self)
#     209 lines = [it.get_declaration()
#     210          for it in self.get_identified_types().values()]
#     211 # Global values (including function definitions)
# --> 212 lines += [str(v) for v in self.globals.values()]
#     213 return lines
#
# File ~/Work/UGR/Calculations/WindTurbines_hybrid/WT_hybrid_venv/lib/python3.10/site-packages/llvmlite/ir/module.py:212, in <listcomp>(.0)
#     209 lines = [it.get_declaration()
#     210          for it in self.get_identified_types().values()]
#     211 # Global values (including function definitions)
# --> 212 lines += [str(v) for v in self.globals.values()]
#     213 return lines
#
# File ~/Work/UGR/Calculations/WindTurbines_hybrid/WT_hybrid_venv/lib/python3.10/site-packages/llvmlite/ir/values.py:1016, in Function.__str__(self)
#    1014 buf = []
#    1015 self.descr(buf)
# -> 1016 return "".join(buf)
#
# KeyboardInterrupt:

# %%
shap.plots.beeswarm(shap_values_default, max_display=10)

# %%
# Removing outliers:
shap_values_default_no_out = shap_values_default
shap_values_default_no_out.values = np.clip(shap_values_default_no_out.values, -20, 20)

shap.plots.beeswarm(shap_values_default_no_out, max_display=10)

# %%
shap.plots.waterfall(shap_values_default[0], max_display=20)

# %%
shap.plots.bar(shap_values_default, max_display=20)

# %% [markdown]
# ## CF Model
#
# Plots for the reduced case after applying correlation filter.

# %%
shap_values_CF = show_shap_values(TEST_CF_PATH, MODEL_CF_PATH, SAMPLES)
# Out:
# 2024-10-02 13:49:08.541871: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:274] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected

# %%
print(shap_values_CF.values.shape)
print(shap_values_CF.base_values.shape)
print(shap_values_CF.data.shape)
shap_values_CF.feature_names
# Out:
# (100, 12)
# (100, 1)
# (100, 12)
# ['theta',
#  'hub_temperature',
#  'nacelle_temperature',
#  'V',
#  'Vane_angle',
#  'Out_temperature',
#  'grid_frecuency',
#  'grid_voltage',
#  'W',
#  'Rotor_temperature',
#  'Wind_angle_c',
#  'nacelle_angle_c']

# %%
# create a dependence scatter plot to show the effect of a single feature across the whole dataset
#shap.plots.scatter(shap_values_CF[:,0], color=shap_values_CF)

# %%
x_id = shap_values_CF.feature_names.index("V")
y_id = shap_values_CF.feature_names.index("V")
plt.scatter(shap_values_CF.data[:,x_id],shap_values_CF.values[:,y_id])
plt.xlabel(shap_values_CF.feature_names[x_id])
plt.ylabel("Shap Value "+shap_values_CF.feature_names[y_id])
# Out:
# Text(0, 0.5, 'Shap Value V')

# %%
shap.plots.beeswarm(shap_values_CF, max_display=20)

# %%
shap.plots.waterfall(shap_values_CF[0], max_display=20)

# %%
shap.plots.bar(shap_values_CF, max_display=20)

# %%
mean_svalues = shap_values_CF.values[:,0:12].mean(axis=0)
print(mean_svalues)
# Out:
# [-5.39329547e-04 -4.61072325e-03  1.30071822e-03  1.58915247e-03
#  -2.90519840e-03  1.05540334e-02 -2.58782205e-05 -1.30302356e-03
#  -7.32362490e-03  3.86043860e-03 -7.31837255e-03  6.72180773e-03]
